# %%
import pandas as pd

my_books = pd.read_csv("my_books.csv", index_col=0)
my_books["book_id"] = my_books["book_id"].astype(str)

# %%
my_books
# Out:
#     user_id   book_id  rating  \
# 0        -1  13271378       5
# 1        -1  11047557       5
# 2        -1     85301       5
# 3        -1  18144590       5
# 4        -1     77203       5
# 5        -1    243714       5
# 6        -1    893172       1
# 7        -1  18918647       5
# 8        -1  11468377       5
# 9        -1      4677       3
# 10       -1   2065487       5
#
#                                                 title
# 0                                             Brother
# 1                               The Lord of the Rings
# 2                                  Unaccustomed Earth
# 3                                       The Alchemist
# 4                                     The Kite Runner
# 5                             Interpreter of Maladies
# 6   Percy Jackson and the Lightning Thief (Percy J...
# 7                                                1984
# 8                             Thinking, Fast and Slow
# 9                                    The Great Gatsby
# 10                Dragonball Vol. 1 (Dragon Ball, #1)

# %%
csv_book_mapping = {}
with open("book_id_map.csv", "r") as f:
    while True:
        line = f.readline()
        if not line:
            break
        csv_id, book_id = line.strip().split(",")
        csv_book_mapping[csv_id] = book_id

# %%
# Each element in a set is unique
my_books_set = set(my_books["book_id"])

# %%
import time

overlap_users = {}

tick = time.perf_counter()
with open("goodreads_interactions.csv", 'r') as f:
    while True:
        line = f.readline()
        if not line:
            break
        user_id, csv_id, _, rating, _ = line.split(",")
        
        book_id = csv_book_mapping.get(csv_id)
        
        if book_id in my_books_set:
            if user_id not in overlap_users:
                overlap_users[user_id] = 1
            else:
                overlap_users[user_id] += 1
tock = time.perf_counter()

elapsed_time_s = int(tock - tick)
m, s = divmod(elapsed_time_s, 60)
print("elapsed time to find overlap users = " + str(m) + " minutes and " + str(s) + " seconds")
# Out:
# elapsed time to find overlap users = 4 minutes and 35 seconds

# %%
# Reduce the overlapped set by filtering out people who read less than 20% of the books the user
my_num_books = my_books.shape[0]
filtered_overlap_users = set([k for k in overlap_users if overlap_users[k] > my_num_books / 5])

# %%
num_overlap_users = len(overlap_users)
num_filtered_overlap_users = len(filtered_overlap_users)
reduction = -100 * (num_filtered_overlap_users - num_overlap_users) / num_overlap_users

# %%
overlap_users_info = {"number of overlap users (at least one common read book)": [num_overlap_users],
                      "number of filtered overlap users (read more than 20% more books)": [num_filtered_overlap_users],
                      "reduction (%)": [reduction]}
overlap_users_info_df = pd.DataFrame.from_dict(overlap_users_info)
overlap_users_info_df
# Out:
#    number of overlap users (at least one common read book)  \
# 0                                             178488
#
#    number of filtered overlap users (read more than 20% more books)  \
# 0                                               1342
#
#    reduction (%)
# 0      99.248129

# %%
interactions_list = []

# Determine the book list of the people who read at least one of the books that the user read and has read more than 20% more books than the user
tick = time.perf_counter()
with open("goodreads_interactions.csv", 'r') as f:
    while True:
        line = f.readline()
        if not line:
            break
        user_id, csv_id, _, rating, _ = line.split(",")
        
        if user_id in filtered_overlap_users:
            book_id = csv_book_mapping[csv_id]
            interactions_list.append([user_id, book_id, rating])
tock = time.perf_counter()

elapsed_time_s = int(tock - tick)
m, s = divmod(elapsed_time_s, 60)
print("elapsed time to find overlap and filtered users' read book list = " + str(m) + " minutes and " + str(s) + " seconds")
# Out:
# elapsed time to find overlap and filtered users' read book list = 3 minutes and 3 seconds

# %%
num_interactions = len(interactions_list)
print("number of people to collaborate with = " + str(num_filtered_overlap_users))
print("number of ratings to use = " + str(num_interactions))
# Out:
# number of people to collaborate with = 1342
# number of ratings to use = 2839027

# %%
interactions = pd.DataFrame(interactions_list, columns=["user_id", "book_id", "rating"])
# add user's read books to interactions
interactions = pd.concat([my_books[["user_id", "book_id", "rating"]], interactions])

# %%
interactions
# Out:
#         user_id   book_id rating
# 0            -1  13271378      5
# 1            -1  11047557      5
# 2            -1     85301      5
# 3            -1  18144590      5
# 4            -1     77203      5
# ...         ...       ...    ...
# 2839022  875017     14756      4
# 2839023  875017      5139      4
# 2839024  875017      5191      4
# 2839025  875017     85301      3
# 2839026  875017   6411961      3
#
# [2839038 rows x 3 columns]

# %%
interactions["book_id"] = interactions["book_id"].astype(str)
interactions["user_id"] = interactions["user_id"].astype(str)

interactions["rating"] = pd.to_numeric(interactions["rating"])

interactions["user_index"] = interactions["user_id"].astype("category").cat.codes
interactions["book_index"] = interactions["book_id"].astype("category").cat.codes

# %%
# Number of unique users (will be one more than num_filtered_overlap_users because added user)
num_unique_users = len(interactions.user_id.unique())
num_book_ratings = len(interactions.book_id.unique())
matrix_size = num_unique_users * num_book_ratings
print("matrix_size = num_users * num_book_ratings = " + str(num_unique_users) + " x " + str(num_book_ratings) + " = " + str(matrix_size))
# Out:
# matrix_size = num_users * num_book_ratings = 1343 x 570134 = 765689962

# %%
from scipy.sparse import coo_matrix

# Need to make matrix sparse to reduce computational overhead (dense to sparse matrix)
# Data, row, column
ratings_mat_coo = coo_matrix((interactions["rating"], (interactions["user_index"], interactions["book_index"])))

# %%
ratings_mat_coo
# Out:
# <1343x570134 sparse matrix of type '<class 'numpy.int64'>'
# 	with 2839038 stored elements in COOrdinate format>

# %%
ratings_mat = ratings_mat_coo.tocsr()

# %%
interactions[interactions["user_id"] == "-1"]
# Out:
#    user_id   book_id  rating  user_index  book_index
# 0       -1  13271378       5           0       71341
# 1       -1  11047557       5           0       22088
# 2       -1     85301       5           0      535954
# 3       -1  18144590       5           0      173010
# 4       -1     77203       5           0      511400
# 5       -1    243714       5           0      279484
# 6       -1    893172       1           0      546282
# 7       -1  18918647       5           0      197424
# 8       -1  11468377       5           0       31841
# 9       -1      4677       3           0      427066
# 10      -1   2065487       5           0      217133

# %%
my_index = 0

# %%
from sklearn.metrics.pairwise import cosine_similarity

similarity = cosine_similarity(ratings_mat[my_index,:], ratings_mat).flatten()

# %%
similarity[0]
# Out:
# 1.0

# %%
import numpy as np

indices = np.argpartition(similarity, -15)[-15:]

# %%
indices
# Out:
# array([ 707, 1225, 1261,  709,  956, 1194, 1125, 1310, 1139, 1221,  681,
#        1145, 1176, 1300,    0], dtype=int64)

# %%
similar_users = interactions[interactions["user_index"].isin(indices)].copy()

# %%
similar_users = similar_users[similar_users["user_id"] != "-1"]

# %%
similar_users
# Out:
#         user_id  book_id  rating  user_index  book_index
# 2094031  326216   342251       0         681      391343
# 2094032  326216    10210       0         681        4288
# 2094033  326216   110824       0         681       22949
# 2094034  326216   227186       0         681      250520
# 2094035  326216   263862       0         681      315985
# ...         ...      ...     ...         ...         ...
# 2839022  875017    14756       4        1310       99717
# 2839023  875017     5139       4        1310      436098
# 2839024  875017     5191       4        1310      437032
# 2839025  875017    85301       3        1310      535954
# 2839026  875017  6411961       3        1310      469192
#
# [2001 rows x 5 columns]

# %%
book_recs = similar_users.groupby("book_id").rating.agg(['count', 'mean'])

# %%
book_recs
# Out:
#           count      mean
# book_id
# 100286        1  0.000000
# 100322        1  0.000000
# 10032672      1  0.000000
# 10054335      1  0.000000
# 100915        1  0.000000
# ...         ...       ...
# 99561         3  2.333333
# 99664         1  0.000000
# 998133        1  2.000000
# 9994765       1  0.000000
# 9999107       1  0.000000
#
# [1723 rows x 2 columns]

# %%
books_titles = pd.read_json("book_info_df.json")
books_titles["book_id"] = books_titles["book_id"].astype(str)
book_recs = book_recs.merge(books_titles, how="inner", on="book_id")

# %%
book_recs
# Out:
#        book_id  count      mean  \
# 0       100286      1  0.000000
# 1       100322      1  0.000000
# 2     10032672      1  0.000000
# 3     10054335      1  0.000000
# 4       100915      1  0.000000
# ...        ...    ...       ...
# 1674     99561      3  2.333333
# 1675     99664      1  0.000000
# 1676    998133      1  2.000000
# 1677   9994765      1  0.000000
# 1678   9999107      1  0.000000
#
#                                                   title  num_ratings  \
# 0                         A Short Guide to a Happy Life         6217
# 1                              Assata: An Autobiography        11057
# 2                               The Language of Flowers       142582
# 3                                     Rules of Civility        78912
# 4     The Lion, the Witch, and the Wardrobe (Chronic...      1575387
# ...                                                 ...          ...
# 1674                                 Looking for Alaska       804587
# 1675                                   The Painted Veil        24606
# 1676                                      The Gathering        14548
# 1677            My Soul to Take (African Immortals, #4)          634
# 1678                               The American Heiress        24522
#
#                                                     url  \
# 0     https://www.goodreads.com/book/show/100286.A_S...
# 1     https://www.goodreads.com/book/show/100322.Assata
# 2     https://www.goodreads.com/book/show/10032672-t...
# 3     https://www.goodreads.com/book/show/10054335-r...
# 4     https://www.goodreads.com/book/show/100915.The...
# ...                                                 ...
# 1674  https://www.goodreads.com/book/show/99561.Look...
# 1675  https://www.goodreads.com/book/show/99664.The_...
# 1676  https://www.goodreads.com/book/show/998133.The...
# 1677  https://www.goodreads.com/book/show/9994765-my...
# 1678  https://www.goodreads.com/book/show/9999107-th...
#
#                                             cover_image language_code  \
# 0     https://images.gr-assets.com/books/1320522593m...
# 1     https://images.gr-assets.com/books/1328857268m...           eng
# 2     https://images.gr-assets.com/books/1333577674m...           eng
# 3     https://images.gr-assets.com/books/1311705045m...           eng
# 4     https://images.gr-assets.com/books/1353029077m...           eng
# ...                                                 ...           ...
# 1674  https://images.gr-assets.com/books/1394798630m...           eng
# 1675  https://images.gr-assets.com/books/1320421719m...           eng
# 1676  https://s.gr-assets.com/assets/nophoto/book/11...           eng
# 1677  https://s.gr-assets.com/assets/nophoto/book/11...
# 1678  https://images.gr-assets.com/books/1307342832m...           eng
#
#       average_rating                 publisher  num_pages  publication_year  \
# 0               3.96              random house       50.0            2000.0
# 1               4.47      chicago review press      274.0            1999.0
# 2               4.07          ballantine books      323.0            2011.0
# 3               3.99              viking adult      335.0            2011.0
# 4               4.19  harpercollins publishers      206.0            2005.0
# ...              ...                       ...        ...               ...
# 1674            4.08                     speak      221.0            2006.0
# 1675            3.91                                246.0               NaN
# 1676            3.04     grove press black cat      261.0            2007.0
# 1677            4.22                                  NaN               NaN
# 1678            3.42                                468.0               NaN
#
#                                               mod_title
# 0                         a short guide to a happy life
# 1                               assata an autobiography
# 2                               the language of flowers
# 3                                     rules of civility
# 4     the lion the witch and the wardrobe chronicles...
# ...                                                 ...
# 1674                                 looking for alaska
# 1675                                   the painted veil
# 1676                                      the gathering
# 1677                my soul to take african immortals 4
# 1678                               the american heiress
#
# [1679 rows x 13 columns]

# %%
book_recs["adjusted_count"] = book_recs["count"] * (book_recs["count"] / book_recs["num_ratings"])
book_recs["score"] = book_recs["mean"] * book_recs["adjusted_count"]
book_recs = book_recs[~book_recs["book_id"].isin(my_books["book_id"])]
my_books["mod_title"] = my_books["title"].str.replace("[^a-zA-Z0-9 ]", "", regex=True).str.lower()
my_books["mod_title"] = my_books["mod_title"].str.replace("\s+", " ", regex=True)
book_recs = book_recs[~book_recs["mod_title"].isin(my_books["mod_title"])]
book_recs = book_recs[book_recs["mean"] >= 4]
book_recs = book_recs[book_recs["count"]> 2]

# %%
top_recs = book_recs.sort_values("mean", ascending=False)

# %%
def make_clickable(val):
    return '<a target="_blank" href="{}">Goodreads</a>'.format(val, val)

def show_image(val):
    return '<a href="{}"><img src="{}" width=50></img></a>'.format(val, val)

top_recs.style.format({'url': make_clickable, 'cover_image': show_image})
# Out:
# <style type="text/css">
# </style>
# <table id="T_bd1c6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bd1c6_level0_col0" class="col_heading level0 col0" >book_id</th>
#       <th id="T_bd1c6_level0_col1" class="col_heading level0 col1" >count</th>
#       <th id="T_bd1c6_level0_col2" class="col_heading level0 col2" >mean</th>
#       <th id="T_bd1c6_level0_col3" class="col_heading level0 col3" >title</th>
#       <th id="T_bd1c6_level0_col4" class="col_heading level0 col4" >num_ratings</th>
#       <th id="T_bd1c6_level0_col5" class="col_heading level0 col5" >url</th>
#       <th id="T_bd1c6_level0_col6" class="col_heading level0 col6" >cover_image</th>
#       <th id="T_bd1c6_level0_col7" class="col_heading level0 col7" >language_code</th>
#       <th id="T_bd1c6_level0_col8" class="col_heading level0 col8" >average_rating</th>
#       <th id="T_bd1c6_level0_col9" class="col_heading level0 col9" >publisher</th>
#       <th id="T_bd1c6_level0_col10" class="col_heading level0 col10" >num_pages</th>
#       <th id="T_bd1c6_level0_col11" class="col_heading level0 col11" >publication_year</th>
#       <th id="T_bd1c6_level0_col12" class="col_heading level0 col12" >mod_title</th>
#       <th id="T_bd1c6_level0_col13" class="col_heading level0 col13" >adjusted_count</th>
#       <th id="T_bd1c6_level0_col14" class="col_heading level0 col14" >score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bd1c6_level0_row0" class="row_heading level0 row0" >11</th>
#       <td id="T_bd1c6_row0_col0" class="data row0 col0" >10235</td>
#       <td id="T_bd1c6_row0_col1" class="data row0 col1" >3</td>
#       <td id="T_bd1c6_row0_col2" class="data row0 col2" >4.666667</td>
#       <td id="T_bd1c6_row0_col3" class="data row0 col3" >Mountains Beyond Mountains: The Quest of Dr. Paul Farmer, A Man Who Would Cure the World</td>
#       <td id="T_bd1c6_row0_col4" class="data row0 col4" >53936</td>
#       <td id="T_bd1c6_row0_col5" class="data row0 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/10235.Mountains_Beyond_Mountains">Goodreads</a></td>
#       <td id="T_bd1c6_row0_col6" class="data row0 col6" ><a href="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png"><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></a></td>
#       <td id="T_bd1c6_row0_col7" class="data row0 col7" >eng</td>
#       <td id="T_bd1c6_row0_col8" class="data row0 col8" >4.210000</td>
#       <td id="T_bd1c6_row0_col9" class="data row0 col9" ></td>
#       <td id="T_bd1c6_row0_col10" class="data row0 col10" >333.000000</td>
#       <td id="T_bd1c6_row0_col11" class="data row0 col11" >nan</td>
#       <td id="T_bd1c6_row0_col12" class="data row0 col12" >mountains beyond mountains the quest of dr paul farmer a man who would cure the world</td>
#       <td id="T_bd1c6_row0_col13" class="data row0 col13" >0.000167</td>
#       <td id="T_bd1c6_row0_col14" class="data row0 col14" >0.000779</td>
#     </tr>
#     <tr>
#       <th id="T_bd1c6_level0_row1" class="row_heading level0 row1" >877</th>
#       <td id="T_bd1c6_row1_col0" class="data row1 col0" >2657</td>
#       <td id="T_bd1c6_row1_col1" class="data row1 col1" >5</td>
#       <td id="T_bd1c6_row1_col2" class="data row1 col2" >4.400000</td>
#       <td id="T_bd1c6_row1_col3" class="data row1 col3" >To Kill a Mockingbird</td>
#       <td id="T_bd1c6_row1_col4" class="data row1 col4" >3255518</td>
#       <td id="T_bd1c6_row1_col5" class="data row1 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/2657.To_Kill_a_Mockingbird">Goodreads</a></td>
#       <td id="T_bd1c6_row1_col6" class="data row1 col6" ><a href="https://images.gr-assets.com/books/1361975680m/2657.jpg"><img src="https://images.gr-assets.com/books/1361975680m/2657.jpg" width=50></img></a></td>
#       <td id="T_bd1c6_row1_col7" class="data row1 col7" >eng</td>
#       <td id="T_bd1c6_row1_col8" class="data row1 col8" >4.260000</td>
#       <td id="T_bd1c6_row1_col9" class="data row1 col9" >harper perennial modern classics</td>
#       <td id="T_bd1c6_row1_col10" class="data row1 col10" >324.000000</td>
#       <td id="T_bd1c6_row1_col11" class="data row1 col11" >2006.000000</td>
#       <td id="T_bd1c6_row1_col12" class="data row1 col12" >to kill a mockingbird</td>
#       <td id="T_bd1c6_row1_col13" class="data row1 col13" >0.000008</td>
#       <td id="T_bd1c6_row1_col14" class="data row1 col14" >0.000034</td>
#     </tr>
#     <tr>
#       <th id="T_bd1c6_level0_row2" class="row_heading level0 row2" >162</th>
#       <td id="T_bd1c6_row2_col0" class="data row2 col0" >128029</td>
#       <td id="T_bd1c6_row2_col1" class="data row2 col1" >10</td>
#       <td id="T_bd1c6_row2_col2" class="data row2 col2" >4.200000</td>
#       <td id="T_bd1c6_row2_col3" class="data row2 col3" >A Thousand Splendid Suns</td>
#       <td id="T_bd1c6_row2_col4" class="data row2 col4" >835172</td>
#       <td id="T_bd1c6_row2_col5" class="data row2 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/128029.A_Thousand_Splendid_Suns">Goodreads</a></td>
#       <td id="T_bd1c6_row2_col6" class="data row2 col6" ><a href="https://images.gr-assets.com/books/1345958969m/128029.jpg"><img src="https://images.gr-assets.com/books/1345958969m/128029.jpg" width=50></img></a></td>
#       <td id="T_bd1c6_row2_col7" class="data row2 col7" >eng</td>
#       <td id="T_bd1c6_row2_col8" class="data row2 col8" >4.340000</td>
#       <td id="T_bd1c6_row2_col9" class="data row2 col9" ></td>
#       <td id="T_bd1c6_row2_col10" class="data row2 col10" >372.000000</td>
#       <td id="T_bd1c6_row2_col11" class="data row2 col11" >nan</td>
#       <td id="T_bd1c6_row2_col12" class="data row2 col12" >a thousand splendid suns</td>
#       <td id="T_bd1c6_row2_col13" class="data row2 col13" >0.000120</td>
#       <td id="T_bd1c6_row2_col14" class="data row2 col14" >0.000503</td>
#     </tr>
#     <tr>
#       <th id="T_bd1c6_level0_row3" class="row_heading level0 row3" >434</th>
#       <td id="T_bd1c6_row3_col0" class="data row3 col0" >1774836</td>
#       <td id="T_bd1c6_row3_col1" class="data row3 col1" >3</td>
#       <td id="T_bd1c6_row3_col2" class="data row3 col2" >4.000000</td>
#       <td id="T_bd1c6_row3_col3" class="data row3 col3" >The Palace of Illusions</td>
#       <td id="T_bd1c6_row3_col4" class="data row3 col4" >17085</td>
#       <td id="T_bd1c6_row3_col5" class="data row3 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/1774836.The_Palace_of_Illusions">Goodreads</a></td>
#       <td id="T_bd1c6_row3_col6" class="data row3 col6" ><a href="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png"><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></a></td>
#       <td id="T_bd1c6_row3_col7" class="data row3 col7" >eng</td>
#       <td id="T_bd1c6_row3_col8" class="data row3 col8" >4.110000</td>
#       <td id="T_bd1c6_row3_col9" class="data row3 col9" >doubleday</td>
#       <td id="T_bd1c6_row3_col10" class="data row3 col10" >360.000000</td>
#       <td id="T_bd1c6_row3_col11" class="data row3 col11" >2008.000000</td>
#       <td id="T_bd1c6_row3_col12" class="data row3 col12" >the palace of illusions</td>
#       <td id="T_bd1c6_row3_col13" class="data row3 col13" >0.000527</td>
#       <td id="T_bd1c6_row3_col14" class="data row3 col14" >0.002107</td>
#     </tr>
#     <tr>
#       <th id="T_bd1c6_level0_row4" class="row_heading level0 row4" >1226</th>
#       <td id="T_bd1c6_row4_col0" class="data row4 col0" >4214</td>
#       <td id="T_bd1c6_row4_col1" class="data row4 col1" >4</td>
#       <td id="T_bd1c6_row4_col2" class="data row4 col2" >4.000000</td>
#       <td id="T_bd1c6_row4_col3" class="data row4 col3" >Life of Pi</td>
#       <td id="T_bd1c6_row4_col4" class="data row4 col4" >1012471</td>
#       <td id="T_bd1c6_row4_col5" class="data row4 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/4214.Life_of_Pi">Goodreads</a></td>
#       <td id="T_bd1c6_row4_col6"

# %%
print(top_recs)
# Out:
#       book_id  count      mean  \
# 11      10235      3  4.666667
# 877      2657      5  4.400000
# 162    128029     10  4.200000
# 434   1774836      3  4.000000
# 1226     4214      4  4.000000
# 1657      968      3  4.000000
#
#                                                   title  num_ratings  \
# 11    Mountains Beyond Mountains: The Quest of Dr. P...        53936
# 877                               To Kill a Mockingbird      3255518
# 162                            A Thousand Splendid Suns       835172
# 434                             The Palace of Illusions        17085
# 1226                                         Life of Pi      1012471
# 1657             The Da Vinci Code (Robert Langdon, #2)      1465770
#
#                                                     url  \
# 11    https://www.goodreads.com/book/show/10235.Moun...
# 877   https://www.goodreads.com/book/show/2657.To_Ki...
# 162   https://www.goodreads.com/book/show/128029.A_T...
# 434   https://www.goodreads.com/book/show/1774836.Th...
# 1226  https://www.goodreads.com/book/show/4214.Life_...
# 1657  https://www.goodreads.com/book/show/968.The_Da...
#
#                                             cover_image language_code  \
# 11    https://s.gr-assets.com/assets/nophoto/book/11...           eng
# 877   https://images.gr-assets.com/books/1361975680m...           eng
# 162   https://images.gr-assets.com/books/1345958969m...           eng
# 434   https://s.gr-assets.com/assets/nophoto/book/11...           eng
# 1226  https://images.gr-assets.com/books/1320562005m...
# 1657  https://images.gr-assets.com/books/1303252999m...           eng
#
#       average_rating                         publisher  num_pages  \
# 11              4.21                                        333.0
# 877             4.26  harper perennial modern classics      324.0
# 162             4.34                                        372.0
# 434             4.11                         doubleday      360.0
# 1226            3.88                        seal books      460.0
# 1657            3.79                            anchor      481.0
#
#       publication_year                                          mod_title  \
# 11                 NaN  mountains beyond mountains the quest of dr pau...
# 877             2006.0                              to kill a mockingbird
# 162                NaN                           a thousand splendid suns
# 434             2008.0                            the palace of illusions
# 1226            2006.0                                         life of pi
# 1657            2006.0                 the da vinci code robert langdon 2
#
#       adjusted_count     score
# 11          0.000167  0.000779
# 877         0.000008  0.000034
# 162         0.000120  0.000503
# 434         0.000527  0.002107
# 1226        0.000016  0.000063
# 1657        0.000006  0.000025

# %%
print(type(top_recs))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
test_string = "13271378,5,Brother;11047557,5,The Lord of the Rings;85301,5,Unaccustomed Earth;18144590,5,The Alchemist"
print(test_string)
# Out:
# 13271378,5,Brother;11047557,5,The Lord of the Rings;85301,5,Unaccustomed Earth;18144590,5,The Alchemist

# %%
test_string_list = []
p1 = 0
p2 = 0
for letter in test_string:
    p2 += 1
    if letter == ';':
        test_string_list.append(test_string[p1:p2 - 1].split(","))
        p1 = p2

# %%
for e in test_string_list:
    print(e)
# Out:
# ['13271378', '5', 'Brother']
# ['11047557', '5', 'The Lord of the Rings']
# ['85301', '5', 'Unaccustomed Earth']

# %%
my_books = pd.DataFrame(test_string_list, columns=['book_id', 'rating', 'title'])
my_books["book_id"] = my_books["book_id"].astype(str)
my_books.insert(0, 'user_id', -1)
print(my_books)
# Out:
#    user_id   book_id rating                  title
# 0       -1  13271378      5                Brother
# 1       -1  11047557      5  The Lord of the Rings
# 2       -1     85301      5     Unaccustomed Earth
